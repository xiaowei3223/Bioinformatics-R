# %%
library(MASS)

# %%
cancer <- read.table("cancer.txt",header=TRUE, sep="\t")
# Out:
# Warning message in scan(file = file, what = what, sep = sep, quote = quote, dec = dec, :
# "EOF within quoted string"Warning message in scan(file = file, what = what, sep = sep, quote = quote, dec = dec, :
# "number of items read is not a multiple of the number of columns"

# %%
head(cancer)
# Out:
#   Image.Id. Gene.Description
# 1 21652     catenin (cadherin-associated protein), alpha 1 (102kD)
# 2 25725     farnesyl-diphosphate farnesyltransferase 1
# 3 26184     phosphofructokinase, platelet
# 4 22260     cytochrome c-1
# 5 22293     uroporphyrinogen III synthase (congenital erythropoietic porphyria)
# 6 22493     ribosomal protein L26
#   EWS.T1 EWS.T2 EWS.T3 EWS.T4 EWS.T6 EWS.T7 EWS.T9 EWS.T11 ... TEST.20 TEST.17
# 1 3.2025 1.6547 3.2779 1.0060 2.7098 2.0588 1.8483 2.7140  ... 3.0381  3.7487
# 2 0.0681 0.0710 0.1160 0.1906 0.2367 0.0823 0.1234 0.1805  ... 0.1378  1.6411
# 3 1.0460 1.0409 0.8926 0.4302 0.3693 0.9021 0.9983 0.4964  ... 1.2505  1.0424
# 4 0.1243 0.0520 0.1014 0.1035 0.2190 0.1288 0.2203 0.2509  ... 0.2309  0.2140
# 5 0.4941 0.2045 0.2818 0.2984 0.3711 0.3961 0.3766 0.4754  ... 0.3002  0.1965
# 6 3.1207 2.1609 1.9773 1.6804 1.7800 1.7199 1.7551 3.2509  ... 4.5095  0.3060
#   TEST.18 TEST.22 TEST.16 TEST.23 TEST.14 TEST.25 TEST.15 TEST.19
# ...

# %%
train_row <- sample(1:80, 60)

# %%
class(train_row)
# Out:
# [1] "integer"

# %%
train <- cancer[train_row,]
test <- cancer[-train_row,]

# %%
testClass <- test$
testClass
# Out:
#  [1] catenin (cadherin-associated protein), alpha 1 (102kD)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           
# ...

# %%
test$Gene.Description <-

# %%
myLD <- lda(Gene.Description ~ .,train)
# Out:
# Warning message in lda.default(x, grouping, ...):
# ...
